# %%
from okx_quant.utils.config_utils import ConfigUtils
from okx_quant.data.kline import Kline

config_path = '../config/config.toml'
config_utils = ConfigUtils(config_path)
api_config = config_utils.api_config
config = config_utils.config

# %%
kline = Kline(api_config, config)
kline

# %%
df = kline.get_history_kline('BTC-USDT', '2024-01-01', '2024-12-20')
df
# Out:
#       timestamp      open      high       low     close           vol  \
# 0    2024-01-02   42783.9   45884.6   42662.9   45183.9  22457.941204
# 1    2024-01-03   45184.0   45515.8   40157.3   42985.9  36954.958221
# 2    2024-01-04   42990.0   44349.7   41759.0   44057.7  22396.142675
# 3    2024-01-05   44057.8   44888.0   42250.1   43500.2  25219.900846
# 4    2024-01-06   43500.1   44393.0   43082.6   43865.1  11218.630206
# ..          ...       ...       ...       ...       ...           ...
# 348  2024-12-15  101624.2  103360.7  100606.9  102696.9   4526.306493
# 349  2024-12-16  102696.9  106660.8  102580.5  106319.9  10591.116908
# 350  2024-12-17  106324.7  108365.0  105461.5  106471.0  10071.252194
# 351  2024-12-18  106471.1  107636.3  103113.2  104427.3   9900.932417
# 352  2024-12-19  104432.5  104983.4   98770.1  100676.1  18639.583384
#
#            volCcy   volCcyQuote  confirm
# 0    1.006832e+09  1.006832e+09      1.0
# 1    1.591569e+09  1.591569e+09      1.0
# 2    9.634399e+08  9.634399e+08      1.0
# 3    1.105587e+09  1.105587e+09      1.0
# 4    4.905811e+08  4.905811e+08      1.0
# ..            ...           ...      ...
# 348  4.625642e+08  4.625642e+08      1.0
# 349  1.110469e+09  1.110469e+09      1.0
# 350  1.075927e+09  1.075927e+09      1.0
# 351  1.039491e+09  1.039491e+09      1.0
# 352  1.890489e+09  1.890489e+09      1.0
#
# [353 rows x 9 columns]
