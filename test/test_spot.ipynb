# %%
import toml
import okx.Trade as Trade

# params
api_config = toml.load('../config/api.toml')
api_key = api_config['api_key']
secret_key = api_config['secret_key']
passphrase = api_config['passphrase']
demo_flag = '0'
domain = 'https://www.iihvvs.com'
debug_flag = False

# %% [markdown]
# ## spot market data

# %%
import okx.MarketData as MarketData

market_api = MarketData.MarketAPI(flag=demo_flag, domain=domain, debug=debug_flag)

result = market_api.get_tickers(instType='SPOT')
print(result)
result = market_api.get_ticker(instId='SOL-USDT')
print(result)
# Out:
# {'code': '0', 'msg': '', 'data': [{'instType': 'SPOT', 'instId': '1INCH-EUR', 'last': '0.5626', 'lastSz': '460.345887', 'askPx': '', 'askSz': '0', 'bidPx': '0.5364', 'bidSz': '427.137025', 'open24h': '0.5626', 'high24h': '0.5626', 'low24h': '0.5626', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1709620685505', 'sodUtc0': '0.5626', 'sodUtc8': '0.5626'}, {'instType': 'SPOT', 'instId': 'MDT-USDT', 'last': '0.09161', 'lastSz': '234.780571', 'askPx': '0.09147', 'askSz': '1691.983176', 'bidPx': '0.09135', 'bidSz': '954.303569', 'open24h': '0.09316', 'high24h': '0.0974', 'low24h': '0.08721', 'volCcy24h': '652856.39048561518', 'vol24h': '7074524.221363', 'ts': '1709620683805', 'sodUtc0': '0.09095', 'sodUtc8': '0.09215'}, {'instType': 'SPOT', 'instId': 'LUNA-USDC', 'last': '0.8433', 'lastSz': '13.8138', 'askPx': '0.8432', 'askSz': '288.2345', 'bidPx': '0.8421', 'bidSz': '352.9196', 'open24h': '0.8583', 'high24h': '0.8684', 'low24h': '0.7941', 'volCcy24h': '61829.97018625', 'vol24h': '74433.8213', 'ts': '1709620685505', 'sodUtc0': '0.821', 'sodUtc8': '0.8456'}, {'instType': 'SPOT', 'instId': 'OAS-USDT', 'last': '0.12205', 'lastSz': '243.6', 'askPx': '0.12206', 'askSz': '159.22', 'bidPx': '0.1219', 'bidSz': '768.78', 'open24h': '0.1251', 'high24h': '0.129', 'low24h': '0.11931', 'volCcy24h': '980136.658163', 'vol24h': '7889506.23', 'ts': '1709620685704', 'sodUtc0': '0.1249', 'sodUtc8': '0.12636'}, {'instType': 'SPOT', 'instId': 'LINK-BTC', 'last': '0.0003085', 'lastSz': '6.75', 'askPx': '0.0003087', 'askSz': '13.5', 'bidPx': '0.0003085', 'bidSz': '13.5', 'open24h': '0.000318', 'high24h': '0.0003218', 'low24h': '0.0002928', 'volCcy24h': '31.0583642528', 'vol24h': '101406.602', 'ts': '1709620685409', 'sodUtc0': '0.0002993', 'sodUtc8': '0.0003082'}, {'instType': 'SPOT', 'instId': 'KNC-USDT', 'last': '0.8024', 'lastSz': '10', 'askPx': '0.8025', 'askSz': '30', 'bidPx': '0.8014', 'bidSz': '190.562549', 'open24h': '0.7841', 'high24h': '0.8462', 'low24h': '0.765', 'volCcy24h': '1344376.7292278811', 'vol24h': '1657600.555325', 'ts': '1709620685511', 'sodUtc0': '0.8177', 'sodUtc8': '0.8312'}, {'instType': 'SPOT', 'instId': 'NEO-BTC', 'last': '0.0002664', 'lastSz': '0.45651', 'askPx': '0.0002688', 'askSz': '93.26618', 'bidPx': '0.0002672', 'bidSz': '28.83317', 'open24h': '0.0002527', 'high24h': '0.000295', 'low24h': '0.0002527', 'volCcy24h': '1.136746507589', 'vol24h': '4161.19962', 'ts': '1709620680305', 'sodUtc0': '0.0002627', 'sodUtc8': '0.0002739'}, {'instType': 'SPOT', 'instId': 'DAI-USDT', 'last': '0.9999', 'lastSz': '1004.809142', 'askPx': '1', 'askSz': '15388.064883', 'bidPx': '0.9999', 'bidSz': '1615.771504', 'open24h': '0.9995', 'high24h': '1.0002', 'low24h': '0.9555', 'volCcy24h': '1867094.5612452091', 'vol24h': '1869972.298172', 'ts': '1709620680010', 'sodUtc0': '0.9986', 'sodUtc8': '0.9993'}, {'instType': 'SPOT', 'instId': 'LUNA-USDT', 'last': '0.8429', 'lastSz': '38.4718', 'askPx': '0.8424', 'askSz': '986.6903', 'bidPx': '0.8419', 'bidSz': '334.335', 'open24h': '0.8528', 'high24h': '0.8672', 'low24h': '0.7929', 'volCcy24h': '12898765.81767572', 'vol24h': '15476072.3807', 'ts': '1709620685411', 'sodUtc0': '0.8221', 'sodUtc8': '0.836'}, {'instType': 'SPOT', 'instId': 'XNO-USDT', 'last': '1.483', 'lastSz': '32.586', 'askPx': '1.49', 'askSz': '129.9456', 'bidPx': '1.48', 'bidSz': '85', 'open24h': '1.671', 'high24h': '1.712', 'low24h': '1.463', 'volCcy24h': '210894.6020295', 'vol24h': '134984.5641', 'ts': '1709620684606', 'sodUtc0': '1.54', 'sodUtc8': '1.654'}, {'instType': 'SPOT', 'instId': 'ATOM-ETH', 'last': '0.003419', 'lastSz': '9.9955', 'askPx': '0.003397', 'askSz': '39.5294', 'bidPx': '0.003393', 'bidSz': '39.5617', 'open24h': '0.003578', 'high24h': '0.00375', 'low24h': '0.003312', 'volCcy24h': '18.6942930276', 'vol24h': '5403.7292', 'ts': '1709620684606', 'sodUtc0': '0.003434', 'sodUtc8': '0.003521'}, {'instType': 'SPOT', 'instId': 'CVX-USDT', 'last': '5.247', 'lastSz': '1', 'askPx': '5.252', 'askSz': '54.047752', 'bidPx': '5.238', 'bidS ...
# {'code': '0', 'msg': '', 'data': [{'instType': 'SPOT', 'instId': 'SOL-USDT', 'last': '131.58', 'lastSz': '7.034666', 'askPx': '131.56', 'askSz': '10', 'bidPx': '131.55', 'bidSz': '35.577793', 'open24h': '128.76', 'high24h': '134.97', 'low24h': '127.33', 'volCcy24h': '275841581.4354384', 'vol24h': '2109287.99745', 'ts': '1709620684906', 'sodUtc0': '133.3', 'sodUtc8': '131.8'}]}

# %% [markdown]
# ## get funding data

# %%
import okx.Funding as Funding

funding_api = Funding.FundingAPI(api_key, secret_key, passphrase,
                                 use_server_time=False, flag=demo_flag,
                                 domain=domain, debug=debug_flag)
result = funding_api.get_balances()
print(result)
# Out:
# {'code': '0', 'data': [], 'msg': ''}

# %% [markdown]
# ## get balance

# %%
import okx.Account as Account

account_api = Account.AccountAPI(api_key, secret_key, passphrase,
                                 use_server_time=False, flag=demo_flag,
                                 domain=domain, debug=debug_flag)
result = account_api.get_account_balance()
data = result['data'][0]  # sub-account 
details = data['details']  # sorted by diff ccy
# Out:
# {'availBal': '0.0056504958310004',
#  'availEq': '0.0056504958310004',
#  'borrowFroz': '',
#  'cashBal': '0.0056504958310004',
#  'ccy': 'USDT',
#  'crossLiab': '',
#  'disEq': '53.89219882557151',
#  'eq': '53.87442026688344',
#  'eqUsd': '53.89219882557151',
#  'fixedBal': '0',
#  'frozenBal': '53.86876977105244',
#  'imr': '0',
#  'interest': '',
#  'isoEq': '0',
#  'isoLiab': '',
#  'isoUpl': '0',
#  'liab': '',
#  'maxLoan': '',
#  'mgnRatio': '',
#  'mmr': '0',
#  'notionalLever': '0',
#  'ordFrozen': '0',
#  'rewardBal': '0',
#  'smtSyncEq': '0',
#  'spotInUseAmt': '',
#  'spotIsoBal': '0',
#  'stgyEq': '53.86876977105244',
#  'twap': '0',
#  'uTime': '1709613158513',
#  'upl': '0',
#  'uplLiab': ''}

# %% [markdown]
# # get trading pairs

# %%
import okx.PublicData as PublicData

public_data_api = PublicData.PublicAPI(api_key, secret_key, passphrase,
                                       use_server_time=False, flag=demo_flag,
                                       domain=domain, debug=debug_flag)
result = public_data_api.get_instruments(instType='SPOT')
result
# Out:
# {'code': '0',
#  'data': [{'alias': '',
#    'baseCcy': 'BTC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'BTC-BRL',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1707291027000',
#    'lotSz': '0.00000001',
#    'maxIcebergSz': '9999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999.0000000000000000',
#    'maxTwapSz': '9999999999.0000000000000000',
#    'minSz': '0.00001',
#    'optType': '',
#    'quoteCcy': 'BRL',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ETH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ETH-BRL',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1707291050000',
#    'lotSz': '0.0000001',
#    'maxIcebergSz': '99999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999.0000000000000000',
#    'maxTwapSz': '99999999999.0000000000000000',
#    'minSz': '0.0001',
#    'optType': '',
#    'quoteCcy': 'BRL',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'USDT',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'USDT-BRL',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1707290990000',
#    'lotSz': '0.00001',
#    'maxIcebergSz': '9999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'BRL',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'BTC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'BTC-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.00000001',
#    'maxIcebergSz': '9999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999.0000000000000000',
#    'maxTwapSz': '9999999999.0000000000000000',
#    'minSz': '0.00001',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ETH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ETH-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.0001',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'SOL',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'SOL-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.01',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'DOGE',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'DOGE-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'SHIB',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'SHIB-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '50000',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': '1INCH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': '1INCH-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ADA',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ADA-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AVAX',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AVAX-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'COMP',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'COMP-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'CRV',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'CRV-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'DOT',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'DOT-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'DYDX',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'DYDX-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'EOS',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'EOS-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'LINK',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'LINK-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'LTC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'LTC-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.01',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'SUSHI',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'SUSHI-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700049700000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'TRX',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'TRX-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'UNI',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'UNI-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'USDT',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'USDT-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700049002000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'USDC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'USDC-EUR',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1700539798000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'EUR',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'BTC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'BTC-TRY',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1705545796000',
#    'lotSz': '0.000000001',
#    'maxIcebergSz': '999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999.0000000000000000',
#    'maxTwapSz': '999999999.0000000000000000',
#    'minSz': '0.00001',
#    'optType': '',
#    'quoteCcy': 'TRY',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '1',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ETH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ETH-TRY',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1705545823000',
#    'lotSz': '0.00000001',
#    'maxIcebergSz': '9999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999.0000000000000000',
#    'maxTwapSz': '9999999999.0000000000000000',
#    'minSz': '0.0001',
#    'optType': '',
#    'quoteCcy': 'TRY',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'USDT',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'USDT-TRY',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1698893529000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'TRY',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'BTC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'BTC-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1548133413000',
#    'lotSz': '0.00000001',
#    'maxIcebergSz': '9999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999.0000000000000000',
#    'maxTwapSz': '9999999999.0000000000000000',
#    'minSz': '0.00001',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ETH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ETH-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1548133413000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.0001',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'OKB',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'OKB-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1548133413000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'MATIC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'MATIC-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1617008400000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'XRP',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'XRP-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1548133413000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'SOL',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'SOL-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1601431200000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.01',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'DOGE',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'DOGE-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1548133413000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'SHIB',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'SHIB-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1620452410000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '100000',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'PEPE',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'PEPE-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1682914523000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '1000000',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'SATS',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'SATS-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1702866701000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '2000000',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'MILO',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'MILO-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1648531576000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '20000000000',
#    'maxStopSz': '20000000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '100000000',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'FIL',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'FIL-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1606946433000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'GPT',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'GPT-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1709007454000',
#    'lotSz': '0.001',
#    'maxIcebergSz': '999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999999.0000000000000000',
#    'maxTwapSz': '999999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': '1INCH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': '1INCH-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1608830100000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AAVE',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AAVE-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1603317639000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.01',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ACA',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ACA-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1643100129000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ACE',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ACE-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1702866356000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ACH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ACH-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1682050337000',
#    'lotSz': '0.01',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '100',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ADA',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ADA-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1548133413000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AERGO',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AERGO-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1595456951000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AGIX',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AGIX-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1700803863000',
#    'lotSz': '0.001',
#    'maxIcebergSz': '999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999999.0000000000000000',
#    'maxTwapSz': '999999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AGLD',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AGLD-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1630654581000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AIDOGE',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AIDOGE-USDT',
#    'instType': 'SPOT',
#    'lever': '3',
#    'listTime': '1682391770000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '100000',
#    'maxMktSz': '999999',
#    'maxStopSz': '999999',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '10000000000',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AKITA',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AKITA-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1620979264000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '10000000',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ALCX',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ALCX-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1637910537000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ALGO',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ALGO-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1548133413000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ALPHA',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ALPHA-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1614834000000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ANT',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ANT-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1597255081000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'APE',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'APE-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1647508809000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'API3',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'API3-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1607464841000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'APM',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'APM-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1582320712000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '100',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'APT',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'APT-USDT',
#    'instType': 'SPOT',
#    'lever': '10',
#    'listTime': '1666141200000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AR',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AR-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1640315756000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ARB',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ARB-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1679575630000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ARG',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ARG-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1663915767000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ARTY',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ARTY-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1703127777000',
#    'lotSz': '0.001',
#    'maxIcebergSz': '999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999999.0000000000000000',
#    'maxTwapSz': '999999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AST',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AST-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ASTR',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ASTR-USDT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1642405602000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ATOM',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ATOM-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1548133413000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'USDT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'AUCTION',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'AUCTION-USDT',
#    'instType': 'SPOT',
#    'lever': '5',
#    'listTime': '1617793135000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
# ...
#    'lever': '',
#    'listTime': '1614852000000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'BTC',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'TRX',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'TRX-BTC',
#    'instType': 'SPOT',
#    'lever': '3',
#    'listTime': '1548133413000',
#    'lotSz': '0.01',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'BTC',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'UNI',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'UNI-BTC',
#    'instType': 'SPOT',
#    'lever': '3',
#    'listTime': '1600284608000',
#    'lotSz': '0.00001',
#    'maxIcebergSz': '9999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'BTC',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'WBTC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'WBTC-BTC',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1599973200000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '0.0001',
#    'optType': '',
#    'quoteCcy': 'BTC',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'XCH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'XCH-BTC',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1620064885000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'BTC',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'XLM',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'XLM-BTC',
#    'instType': 'SPOT',
#    'lever': '3',
#    'listTime': '1548133413000',
#    'lotSz': '0.001',
#    'maxIcebergSz': '999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999999.0000000000000000',
#    'maxTwapSz': '999999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'BTC',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'OKB',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'OKB-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'XRP',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'XRP-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '0.001',
#    'maxIcebergSz': '999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999999.0000000000000000',
#    'maxTwapSz': '999999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'SOL',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'SOL-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1601434808000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '0.01',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'DOGE',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'DOGE-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1618901960000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'FIL',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'FIL-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1606950008000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ADA',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ADA-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '1',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ATOM',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ATOM-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'BETH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'BETH-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1608678028000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.001',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'EOS',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'EOS-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'LINK',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'LINK-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '0.001',
#    'maxIcebergSz': '999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999999.0000000000000000',
#    'maxTwapSz': '999999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'LTC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'LTC-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.01',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'OKT',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'OKT-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1611012719000',
#    'lotSz': '0.0001',
#    'maxIcebergSz': '99999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '99999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '99999999999999.0000000000000000',
#    'maxTwapSz': '99999999999999.0000000000000000',
#    'minSz': '0.1',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'STETH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'STETH-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1689650492000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.001',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'TRX',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'TRX-ETH',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1548133413000',
#    'lotSz': '0.01',
#    'maxIcebergSz': '9999999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999999999.0000000000000000',
#    'maxTwapSz': '9999999999999999.0000000000000000',
#    'minSz': '10',
#    'optType': '',
#    'quoteCcy': 'ETH',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00000001',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'BTC',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'BTC-EURT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1658201420000',
#    'lotSz': '0.00000001',
#    'maxIcebergSz': '9999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '9999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '9999999999.0000000000000000',
#    'maxTwapSz': '9999999999.0000000000000000',
#    'minSz': '0.00001',
#    'optType': '',
#    'quoteCcy': 'EURT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': ''},
#   {'alias': '',
#    'baseCcy': 'ETH',
#    'category': '1',
#    'ctMult': '',
#    'ctType': '',
#    'ctVal': '',
#    'ctValCcy': '',
#    'expTime': '',
#    'instFamily': '',
#    'instId': 'ETH-EURT',
#    'instType': 'SPOT',
#    'lever': '',
#    'listTime': '1658201420000',
#    'lotSz': '0.000001',
#    'maxIcebergSz': '999999999999.0000000000000000',
#    'maxLmtAmt': '20000000',
#    'maxLmtSz': '999999999999',
#    'maxMktAmt': '1000000',
#    'maxMktSz': '1000000',
#    'maxStopSz': '1000000',
#    'maxTriggerSz': '999999999999.0000000000000000',
#    'maxTwapSz': '999999999999.0000000000000000',
#    'minSz': '0.001',
#    'optType': '',
#    'quoteCcy': 'EURT',
#    'settleCcy': '',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': ''}],
#  'msg': ''}
